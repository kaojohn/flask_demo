# %%
import pandas as pd
# Out:
# C:\Users\liber\AppData\Local\Temp\ipykernel_11892\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
url1='https://data.moenv.gov.tw/api/v2/aqx_p_02?api_key=e8dd42e6-9b8b-43f8-991e-b3dee723a52d&limit=1000&sort=datacreationdate%20desc&format=CSV'

# %%
df=pd.read_csv(url1).dropna()
df
# Out:
#    site county  pm25  datacreationdate itemunit
# 0    大城    彰化縣    25  2024-03-12 18:00    μg/m3
# 1   富貴角    新北市    23  2024-03-12 18:00    μg/m3
# 2    麥寮    雲林縣    30  2024-03-12 18:00    μg/m3
# 3    關山    臺東縣    17  2024-03-12 18:00    μg/m3
# 4    馬公    澎湖縣    19  2024-03-12 18:00    μg/m3
# ..  ...    ...   ...               ...      ...
# 73   土城    新北市    32  2024-03-12 18:00    μg/m3
# 74   新店    新北市    40  2024-03-12 18:00    μg/m3
# 75   萬里    新北市    26  2024-03-12 18:00    μg/m3
# 76   汐止    新北市    22  2024-03-12 18:00    μg/m3
# 77   基隆    基隆市    31  2024-03-12 18:00    μg/m3
#
# [78 rows x 5 columns]

# %% [markdown]
# ### 取cloumns&values

# %%
cloumns=df.columns.tolist()
cloumns
# Out:
# ['site', 'county', 'pm25', 'datacreationdate', 'itemunit']

# %%
values=df.values.tolist()
values
# Out:
# [['大城', '彰化縣', 25, '2024-03-12 18:00', 'μg/m3'],
#  ['富貴角', '新北市', 23, '2024-03-12 18:00', 'μg/m3'],
#  ['麥寮', '雲林縣', 30, '2024-03-12 18:00', 'μg/m3'],
#  ['關山', '臺東縣', 17, '2024-03-12 18:00', 'μg/m3'],
#  ['馬公', '澎湖縣', 19, '2024-03-12 18:00', 'μg/m3'],
#  ['金門', '金門縣', 22, '2024-03-12 18:00', 'μg/m3'],
#  ['馬祖', '連江縣', 20, '2024-03-12 18:00', 'μg/m3'],
#  ['埔里', '南投縣', 16, '2024-03-12 18:00', 'μg/m3'],
#  ['復興', '高雄市', 14, '2024-03-12 18:00', 'μg/m3'],
#  ['永和', '新北市', 32, '2024-03-12 18:00', 'μg/m3'],
#  ['竹山', '南投縣', 27, '2024-03-12 18:00', 'μg/m3'],
#  ['中壢', '桃園市', 31, '2024-03-12 18:00', 'μg/m3'],
#  ['三重', '新北市', 32, '2024-03-12 18:00', 'μg/m3'],
#  ['冬山', '宜蘭縣', 30, '2024-03-12 18:00', 'μg/m3'],
#  ['宜蘭', '宜蘭縣', 29, '2024-03-12 18:00', 'μg/m3'],
#  ['陽明', '臺北市', 27, '2024-03-12 18:00', 'μg/m3'],
#  ['花蓮', '花蓮縣', 28, '2024-03-12 18:00', 'μg/m3'],
#  ['臺東', '臺東縣', 20, '2024-03-12 18:00', 'μg/m3'],
#  ['恆春', '屏東縣', 19, '2024-03-12 18:00', 'μg/m3'],
# ...
